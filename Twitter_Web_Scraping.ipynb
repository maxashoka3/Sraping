# %% [markdown]
# <a href="https://colab.research.google.com/github/maxashoka3/Sraping/blob/main/Twitter_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ntscraper

# %%
from ntscraper import Nitter
import pandas as pd

# %%
scraper = Nitter(0)
# Out:
# Testing instances: 100%|██████████| 77/77 [02:02<00:00,  1.59s/it]

# %%
tweets = scraper.get_tweets("india", mode = 'hashtag', number=10)
# Out:
# WARNING:root:Empty page on https://nitter.in.projectsegfau.lt

# %%
final_tweets = []
for x in tweets['tweets']:
    data = [x['link'], x['text'],x['date'],x['stats']['likes'],x['stats']['comments']]
    final_tweets.append(data)

# %%
dat = pd.DataFrame(final_tweets, columns =['twitter_link','text','date','likes','comments'])

# %%
dat
# Out:
# Empty DataFrame
# Columns: [twitter_link, text, date, likes, comments]
# Index: []

# %%
tweets = scraper.get_profile_info("JeffBezos")

# %%
tweets
# Out:
# {'image': 'https://pbs.twimg.com/profile_images/1591558315254890500/ETIHb4Nl_400x400.jpg',
#  'name': 'Jeff Bezos',
#  'username': '@JeffBezos',
#  'id': '15506669',
#  'bio': 'Amazon. Blue Origin. Washington Post. Bezos Earth Fund. Bezos Academy.',
#  'location': '',
#  'website': 'https://hoo.be/jeffbezos',
#  'joined': '10:38 PM - 20 Jul 2008',
#  'stats': {'tweets': 397,
#   'following': 323,
#   'followers': 6312480,
#   'likes': 133,
#   'media': 0}}

# %%
tweets['image']
# Out:
# 'https://pbs.twimg.com/profile_images/1591558315254890500/ETIHb4Nl_400x400.jpg'

# %%
def get_tweets(name, modes, no):
    tweets = scraper.get_tweets(name, mode = modes, number=no)
    final_tweets = []
    for x in tweets['tweets']:
        data = [x['link'], x['text'],x['date'],x['stats']['likes'],x['stats']['comments']]
        final_tweets.append(data)
    dat= pd.DataFrame(final_tweets, columns =['twitter_link','text','date','likes','comments'])
    return dat

# %%
data = get_tweets('JeffBezos','user',6)

# %%
data
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/SenBillNelson/status/17179...
# 1  https://twitter.com/torybruno/status/166661245...
# 2  https://twitter.com/JeffBezos/status/165957630...
# 3  https://twitter.com/JeffBezos/status/162522482...
# 4  https://twitter.com/JeffBezos/status/162046673...
# 5  https://twitter.com/JeffBezos/status/161941882...
#
#                                                 text  \
# 0  Impressive visit to the @blueorigin Huntsville...
# 1                                       Nominal run!
# 2  Honored to be on this journey with @NASA to la...
# 3  Big milestone. Kudos and congrats to the whole...
# 4  Episode 3 of Last of Us is unbelievably good s...
# 5        Thank you Bill and Tim. So nice. Gratitude.
#
#                          date  likes  comments
# 0  Oct 27, 2023 · 2:00 PM UTC   3386      1721
# 1   Jun 8, 2023 · 1:05 AM UTC   3815      1037
# 2  May 19, 2023 · 3:06 PM UTC  13048      4527
# ...

# %%
billi = scraper.get_profile_info('BillGates')
# Out:
# WARNING:root:https://nitter.mint.lgbt unreachable. Trying https://nitter.mint.lgbt
# WARNING:root:https://nitter.mint.lgbt unreachable. Trying https://nitter.no-logs.com
# WARNING:root:Fetching error: Instance has been rate limited.Use another instance or try again later.

# %%
billi = scraper.get_profile_info('Birble_AI')

# %%
billi
# Out:
# {'image': 'https://pbs.twimg.com/profile_images/1754931572141146112/-Y4lNT2C_400x400.png',
#  'name': 'Birble AI | Web3 & AI Development Platform',
#  'username': '@Birble_AI',
#  'id': '1026558912022097920',
#  'bio': '🧠 Transforming Ideas into Intelligence 🚀 | Bridging the Gap Between Creativity and Technology 🌟 | Explore the Power of AI with Birble AI! 💡 #ArtificialIntel',
#  'location': '',
#  'website': 'https://Birble.win',
#  'joined': '8:01 PM - 6 Aug 2018',
#  'stats': {'tweets': 16774,
#   'following': 3526,
#   'followers': 5351,
#   'likes': 32939,
#   'media': 0}}

# %%
gau = scraper.get_profile_info("dahalGau")
# Out:
# WARNING:root:Empty page on https://nitter.projectsegfau.lt

# %%
tweets = scraper.get_tweets("india", mode = 'hashtag', number=10)

# %%
b_tweet  = scraper.get_tweets("Birble_AI", mode='user')
# Out:
# WARNING:root:Empty page on https://nitter.projectsegfau.lt

# %%
b_tweet
# Out:
# {'tweets': [], 'threads': []}

# %%
github_hash_tweets = scraper.get_tweets("github", mode='hashtag')

bezos_tweets = scraper.get_tweets("JeffBezos", mode='user')

# %%
github_hash_tweets = scraper.get_tweets("github", mode='hashtag')
# Out:
# WARNING:root:https://nitter.privacydev.net unreachable. Trying https://nitter.privacydev.net
# WARNING:root:https://nitter.privacydev.net unreachable. Trying https://nitter.nohost.network
# WARNING:root:Empty page on https://nitter.nohost.network

# %%
c1 = scraper.get_tweets("ykdojo", mode='user')
# Out:
# WARNING:root:Empty page on https://nitter.tux.pizza

# %%
c1
# Out:
# {'tweets': [{'link': 'https://twitter.com/ykdojo/status/1757812759037948400#m',
#    'text': 'Prediction:  Someone is going to build an open source alternative to StreamYard (a streaming platform) and it’ll eventually be a billion dollar company.  That person will be me.',
#    'user': {'name': 'YK aka CS Dojo 📺🐦',
#     'username': '@ykdojo',
#     'profile_id': '1732269446713217024',
#     'avatar': 'https://pbs.twimg.com/profile_images/1732269446713217024/OrNokBIn_bigger.jpg'},
#    'date': 'Feb 14, 2024 · 5:03 PM UTC',
#    'is-retweet': False,
#    'is-pinned': True,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 31, 'retweets': 23, 'quotes': 4, 'likes': 355},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/ykdojo/status/1759797016723595553#m',
# ...

# %%
bezos_tweets = scraper.get_tweets("elonmusk", mode='user')
# Out:
# WARNING:root:Empty page on https://nitter.no-logs.com

# %%
bezos_tweets
# Out:
# {'tweets': [{'link': 'https://twitter.com/elonmusk/status/1759857255124807757#m',
#    'text': '“Extra” virgin mfw',
#    'user': {'name': 'Elon Musk',
#     'username': '@elonmusk',
#     'profile_id': '1683325380441128960',
#     'avatar': 'https://pbs.twimg.com/profile_images/1683325380441128960/yRsRRjGO_bigger.jpg'},
#    'date': 'Feb 20, 2024 · 8:27 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 5323,
#     'retweets': 6953,
#     'quotes': 531,
#     'likes': 97045},
#    'pictures': ['https://pbs.twimg.com/media/GGxE2LSbgAAZY2e.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/elonmusk/status/1759780859362566395#m',
# ...

# %%
data = get_tweets('elonmusk','user',6)

# %%
data
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/elonmusk/status/1759857255...
# 1  https://twitter.com/elonmusk/status/1759780859...
# 2  https://twitter.com/cb_doge/status/17596578905...
# 3  https://twitter.com/Kristennetten/status/17593...
# 4  https://twitter.com/elonmusk/status/1759592449...
# 5  https://twitter.com/elonmusk/status/1759304979...
#
#                                                 text  \
# 0                                 “Extra” virgin mfw
# 1  From Grok 😂 ——— Roast the whole idea of “conte...
# 2  BREAKING: 𝕏 outperforms other platforms by off...
# 3  Elon Musk & Ilya Sutskever receiving Nvidia ha...
# 4
# 5                                            Exactly
#
#                          date  likes  comments
# 0  Feb 20, 2024 · 8:27 AM UTC  98522      5387
# 1  Feb 20, 2024 · 3:23 AM UTC  39970      6913
# 2  Feb 19, 2024 · 7:15 PM UTC   7498      1131
# 3  Feb 18, 2024 · 7:33 PM UTC   8089       714
# ...
